# %% [markdown]
# # João Pedro de Gois Pinto - PP-P001 - T2

# %% [markdown]
# Aqui estarei fazendo a atividade PP-P001 de Python, Turma 2.

# %% [markdown]
# ### Exercício 2:  Manipulação de variáveis de tipo inteiro, explorando as características e os limites.

# %% [markdown]
# Q: Demonstre como funcionam os operadores aritméticos e aritméticos compostos em Python e destaque as principais novidades e diferenças em relação ao conjunto de operadores com inteiros disponíveis em C/C++ ;

# %%
#Exemplo de operadores aritméticos

a = 100
print(a)
a = a + 2
print(a)
a = a - 2
print(a)
a = 15
a = a / 2
print(a)
# Em python, a divisão entre inteiros pode resultar num número float, diferente de c++, se não deseja a parte fracionária
# precisa usar o operador //, como exemplificado a seguir
a = 15
a = a // 2
print(a)
a = a * 2
print(a)
a = a ** 3
print(a)
a = a % 3
print(a)
# Out:
# 100
# 102
# 100
# 7.5
# 7
# 14
# 2744
# 2

# %%
#Exemplo de operadores aritméticos compostos
a = 100
print(a)
a += 5 
print(a)
a -= 4  
print(a)
a *= 8 
print(a)
a /= 7  
print(a)
a //= 4 
print(a)
a %= 5 
print(a)
a **= 2 
print(a)
# Out:
# 100
# 105
# 101
# 808
# 115.42857142857143
# 28.0
# 3.0
# 9.0

# %% [markdown]
# R: Além das diferenças citadas no comportamento das divisões utilizando / e //, há também a questão que os operadores aritméticos podem ser utilizados com dados de qualquer tipagem, e não apenas numerais.

# %% [markdown]
# Q: Demonstre a possibilidade de representar números inteiros significativamente grandes calculando o fatorial de 30 e comparando o resultado com o maior valor inteiro que pode ser representado em C/C++;

# %%
# Calculando o fatorial de 30
fat = 1
for i in range(1,30):
    fat *= i

print("O fatorial de 30 é: ",fat)
# Out:
# O fatorial de 30 é:  8841761993739701954543616000000

# %% [markdown]
# R: Em contrapartida, em C++ essa mesma operação utilizando uma variável do tipo int resulta no valor "1409286144" dado a limitação no valor nativo para inteiros presente na linguagem. Já em Python, podemos perceber que o número não possui limite, enquanto houver memória disponível.

# %% [markdown]
# Q: As variáveis numéricas são imutáveis. Demonstre com exemplos as implicações desta afirmação;

# %%
# Exemplo de variáveis imutáveis
aux1 = 5 # aux1 referencia um inteiro
aux2 = aux1 # aux2 referencia o mesmo espaço na memória
print("Os valores são os mesmos: ")
print("aux1 = ", aux1)
print("aux2 = ", aux2)
print("Alterando o valor de aux1...")
aux1+=5
print("Agora")
print("aux1 = ", aux1)
print("Mas aux2 não mudou...")
print("aux2 = ", aux2)
# Out:
# Os valores são os mesmos:
# aux1 =  5
# aux2 =  5
# Alterando o valor de aux1...
# Agora
# aux1 =  10
# Mas aux2 não mudou...
# aux2 =  5

# %% [markdown]
# R: Isso demonstra como mesmo as variáveis sendo objetos e estarem apontando para o mesmo espaço de memória, ao alterar uma das variáveis, no caso, aux1, ela aponta para um novo endereço de memória com o seu novo valor, o que faz com que o valor de aux2 não seja alterado.

# %% [markdown]
# Q: Verifique quais métodos estão disponíveis para as variáveis inteiras;

# %%
#Verificando os métodos para as variáveis inteiras.
i = 10;
print(dir(i))
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %% [markdown]
# R: Esse comando 'dir' lista os métodos e atributos possíveis de ser executados com a variável i, que é do tipo inteiro.

# %% [markdown]
# ### Exercício 3: Manipulação de variáveis de tipo string e explorando o uso de print.

# %% [markdown]
# Q: Imprima na tela, utilizando print, cada um dos caracteres numéricos e seu correspondente código numérico. Pesquise como modificar o comportamento do print para imprimir como caractere e como número.

# %%
print("chr - int")
for i in range(10):
    char = str(i)
    inteiro = ord(char)
    # Imprime como caractere
    print(f"'{char}' - {inteiro}")
# Out:
# chr - int
# '0' - 48
# '1' - 49
# '2' - 50
# '3' - 51
# '4' - 52
# '5' - 53
# '6' - 54
# '7' - 55
# '8' - 56
# '9' - 57

# %% [markdown]
# Q: Modifique o exercício anterior para que a saída imprima também o código numérico em octal e em hexadecimal.

# %%
print("chr - int - oct - hex")
for i in range(10):
    char = str(i)
    inteiro = ord(char)
    # Imprime como caractere
    print(f"'{char}' - {inteiro} - {oct(inteiro)} - {hex(inteiro)}")
# Out:
# chr - int - oct - hex
# '0' - 48 - 0o60 - 0x30
# '1' - 49 - 0o61 - 0x31
# '2' - 50 - 0o62 - 0x32
# '3' - 51 - 0o63 - 0x33
# '4' - 52 - 0o64 - 0x34
# '5' - 53 - 0o65 - 0x35
# '6' - 54 - 0o66 - 0x36
# '7' - 55 - 0o67 - 0x37
# '8' - 56 - 0o70 - 0x38
# '9' - 57 - 0o71 - 0x39

# %% [markdown]
# Q: Acrescente ao código do exercício anterior a possibilidade de ler um caractere qualquer e imprima no mesmo formato do inciso anterior. Pesquise como ler um valor da entrada padrão.

# %%
entrada = input("Insira um caracter: ")
char = str(entrada)
inteiro = ord(char)
print(f"'{char}' - {inteiro} - {oct(inteiro)} - {hex(inteiro)}")
# Out:
# Insira um caracter: a
# 'a' - 97 - 0o141 - 0x61

# %% [markdown]
# Q: Pesquise como trabalha Python os caracteres especiais, ‘ç’ e ‘ã’ por exemplo. Acrescente no código do exercício anterior um exemplo que demonstra como usar este recurso

# %%
char = str('ç')
inteiro = ord(char)
print(f"'{char}' - {inteiro} - {oct(inteiro)} - {hex(inteiro)}")

char = str('ã')
inteiro = ord(char)
print(f"'{char}' - {inteiro} - {oct(inteiro)} - {hex(inteiro)}")
# Out:
# 'ç' - 231 - 0o347 - 0xe7
# 'ã' - 227 - 0o343 - 0xe3

# %% [markdown]
# Não é necessário qualquer tipo de tratamento, pois Python trata esses caracteres como unicode.

# %% [markdown]
# ### Exercício 4: Manipulação de variáveis de tipo string e explorando os métodos da classe.

# %% [markdown]
# Q: Declare uma variável nome atribuindo a ela seu nome completo;
#
# Q: Pesquise por funcionalidades já implementadas nas strings e separe em duas variáveis novas seu nome do seu sobrenome;
#
# Q: Verifique qual das duas novas variáveis antecede a outra na ordem alfabética;
#
# Q: Verifique a quantidade de caracteres de cada uma das novas variáveis;
#
# Q: Verifique se seu nome é uma palíndromo;

# %%
nome_completo = "Joao Pedro de Gois Pinto"
nomes = nome_completo.split()
nome = nomes[0] + " " + nomes[1]
sobrenome = nomes[3] + " " + nomes[4] 
print("Nome: ", nome)
print("Sobrenome: ",sobrenome)
if(nome > sobrenome):
    print("Sobrenome é menor")
else:
    print("Nome é menor")
    
print("Quantidade de caracteres em nome: ", len(nome))
print("Quantidade de caracteres em sobrenome: ", len(sobrenome))

palin = nome.replace(" ", "").lower()
if(palin == palin[::-1]):
    print("O nome é palídromo!")
else:
    print("O nome não é palíndromo!")
# Out:
# Nome:  Joao Pedro
# Sobrenome:  Gois Pinto
# Sobrenome é menor
# Quantidade de caracteres em nome:  10
# Quantidade de caracteres em sobrenome:  10
# O nome é palídromo!

# %% [markdown]
# ### Exercício 5: Manipulação de variáveis de ponto flutuante, explorando as características e os limites.

# %% [markdown]
# Q: Demonstre como funcionam os operadores aritméticos e aritméticos compostos em Python;

# %%
#Exemplo de operadores aritméticos
a = 3.5
b = 2.0

soma = a + b
print(f"Soma: {soma}")

subtracao = a - b
print(f"Subtração: {subtracao}")

multiplicacao = a * b
print(f"Multiplicação: {multiplicacao}")

divisao = a / b
print(f"Divisão: {divisao}")

potencia = a ** b
print(f"Potência: {potencia}")
# Out:
# Soma: 5.5
# Subtração: 1.5
# Multiplicação: 7.0
# Divisão: 1.75
# Potência: 12.25

# %% [markdown]
# Semelhante ao que ocorre em operação com números inteiros.

# %%
#Exemplo de operadores aritméticos compostos
a = 4.5
print(a)
a += 5.8
print(a)
a -= 4.1  
print(a)
a *= 8.7 
print(a)
a /= 7.6  
print(a)
a %= 5.21 
print(a)
a **= 2.76
print(a)
# Out:
# 4.5
# 10.3
# 6.200000000000001
# 53.940000000000005
# 7.097368421052632
# 1.8873684210526323
# 5.772506738950866

# %% [markdown]
# Q: Utilizando o operador de exponenciação mostre qual a maior e a menor potência de 2 que pode ser representada com variáveis de ponto flutuante.

# %%
# Inicializa a potência com 0
potencia = 0

# Enquanto conseguirmos representar a potência de 2 sem perder precisão
while True:
    resultado = 2.0 ** potencia
    print(f"2^{potencia} = {resultado}")

    # Verifica se atingimos o limite de precisão
    if resultado == float('inf'):
        print(f"2^{potencia} é infinito, perdendo precisão.")
        break

    # Incrementa a potência
    potencia += 1
# Out:
# 2^0 = 1.0
# 2^1 = 2.0
# 2^2 = 4.0
# 2^3 = 8.0
# 2^4 = 16.0
# 2^5 = 32.0
# 2^6 = 64.0
# 2^7 = 128.0
# 2^8 = 256.0
# 2^9 = 512.0
# 2^10 = 1024.0
# 2^11 = 2048.0
# 2^12 = 4096.0
# 2^13 = 8192.0
# 2^14 = 16384.0
# 2^15 = 32768.0
# 2^16 = 65536.0
# 2^17 = 131072.0
# 2^18 = 262144.0
# 2^19 = 524288.0
# 2^20 = 1048576.0
# 2^21 = 2097152.0
# 2^22 = 4194304.0
# 2^23 = 8388608.0
# 2^24 = 16777216.0
# 2^25 = 33554432.0
# 2^26 = 67108864.0
# 2^27 = 134217728.0
# 2^766 = 3.8812952307517723e+230
# 2^767 = 7.762590461503545e+230
# 2^768 = 1.552518092300709e+231
# 2^769 = 3.105036184601418e+231
# 2^770 = 6.210072369202836e+231
# 2^771 = 1.2420144738405671e+232
# 2^772 = 2.4840289476811343e+232
# 2^773 = 4.968057895362269e+232
# 2^774 = 9.936115790724537e+232
# 2^775 = 1.9872231581449074e+233
# 2^776 = 3.974446316289815e+233
# 2^777 = 7.94889263257963e+233
# 2^778 = 1.589778526515926e+234
# 2^779 = 3.179557053031852e+234
# 2^780 = 6.359114106063704e+234
# 2^781 = 1.2718228212127408e+235
# 2^782 = 2.5436456424254815e+235
# 2^783 = 5.087291284850963e+235
# 2^784 = 1.0174582569701926e+236
# 2^785 = 2.0349165139403852e+236
# 2^786 = 4.0698330278807704e+236
# 2^787 = 8.139666055761541e+236
# 2^788 = 1.6279332111523082e+237
# 2^789 = 3.2558664223046163e+237
# 2^790 = 6.511732844609233e+237
# 2^791 = 1.3023465689218465e+238
# 2^792 = 2.604693137843693e+238
# 2^793 = 5.209386275687386e+238
# 2^794 = 1.0418772551374772e+239
# 2^795 = 2.0837545102749545e+239
# 2^796 = 4.167509020549909e+239
# 2^797 = 8.335018041099818e+239
# 2^798 = 1.6670036082199636e+240
# 2^799 = 3.334007216439927e+240
# 2^800 = 6.668014432879854e+240
# 2^801 = 1.333602886575971e+241
# 2^802 = 2.667205773151942e+241
# 2^803 = 5.334411546303884e+241
# 2^804 = 1.0668823092607767e+242
# 2^805 = 2.1337646185215534e+242
# 2^806 = 4.267529237043107e+242
# 2^807 = 8.535058474086213e+242
# 2^808 = 1.7070116948172427e+243
# 2^809 = 3.4140233896344854e+243
# 2^810 = 6.828046779268971e+243
# 2^811 = 1.3656093558537942e+244
# 2^812 = 2.7312187117075883e+244
# 2^813 = 5.462437423415177e+244
# 2^814 = 1.0924874846830353e+245
# 2^815 = 2.1849749693660706e+245
# 2^816 = 4.3699499387321413e+245
# 2^817 = 8.739899877464283e+245
# 2^818 = 1.7479799754928565e+246
# 2^819 = 3.495959950985713e+246
# 2^820 = 6.991919901971426e+246
# 2^821 = 1.3983839803942852e+247
# 2^822 = 2.7967679607885704e+247
# 2^823 = 5.593535921577141e+247
# 2^824 = 1.1187071843154282e+248
# 2^825 = 2.2374143686308563e+248
# 2^826 = 4.474828737261713e+248
# 2^827 = 8.949657474523425e+248
# 2^828 = 1.789931494904685e+249
# 2^829 = 3.57986298980937e+249
# 2^830 = 7.15972597961874e+249
# 2^831 = 1.431945195923748e+250
# 2^832 = 2.863890391847496e+250
# 2^833 = 5.727780783694992e+250
# 2^834 = 1.1455561567389984e+251
# 2^835 = 2.291112313477997e+251
# 2^836 = 4.582224626955994e+251
# 2^837 = 9.164449253911988e+251
# 2^838 = 1.8328898507823975e+252
# 2^839 = 3.665779701564795e+252
# 2^840 = 7.33155940312959e+252
# 2^841 = 1.466311880625918e+253
# 2^842 = 2.932623761251836e+253
# 2^843 = 5.865247522503672e+253
# 2^844 = 1.1730495045007344e+254
# 2^845 = 2.346099009001469e+254
# 2^846 = 4.692198018002938e+254
# 2^847 = 9.384396036005875e+254
# 2^848 = 1.876879207201175e+255
# 2^849 = 3.75375841440235e+255
# 2^850 = 7.5075168288047e+255
# 2^851 = 1.50150336576094e+256
# 2^852 = 3.00300673152188e+256
# 2^853 = 6.00601346304376e+256
# 2^854 = 1.201202692608752e+257
# 2^855 = 2.402405385217504e+257
# 2^856 = 4.804810770435008e+257
# 2^857 = 9.609621540870016e+257
# 2^858 = 1.9219243081740033e+258
# 2^859 = 3.8438486163480065e+258
# 2^860 = 7.687697232696013e+258
# 2^861 = 1.5375394465392026e+259
# 2^862 = 3.0750788930784052e+259
# 2^863 = 6.150157786156811e+259
# 2^864 = 1.2300315572313621e+260
# 2^865 = 2.4600631144627242e+260
# 2^866 = 4.9201262289254483e+260
# 2^867 = 9.840252457850897e+260
# 2^868 = 1.9680504915701793e+261
# 2^869 = 3.936100983140359e+261
# 2^870 = 7.872201966280717e+261
# 2^871 = 1.5744403932561435e+262
# 2^872 = 3.148880786512287e+262
# 2^873 = 6.297761573024574e+262
# 2^874 = 1.2595523146049148e+263
# 2^875 = 2.5191046292098296e+263
# 2^876 = 5.038209258419659e+263
# 2^877 = 1.0076418516839318e+264
# 2^878 = 2.0152837033678636e+264
# 2^879 = 4.0305674067357273e+264
# 2^880 = 8.061134813471455e+264
# 2^881 = 1.612226962694291e+265
# 2^882 = 3.224453925388582e+265
# 2^883 = 6.448907850777164e+265
# 2^884 = 1.2897815701554327e+266
# 2^885 = 2.5795631403108655e+266
# 2^886 = 5.159126280621731e+266
# 2^887 = 1.0318252561243462e+267
# 2^888 = 2.0636505122486924e+267
# 2^889 = 4.127301024497385e+267
# 2^890 = 8.25460204899477e+267
# 2^891 = 1.650920409798954e+268
# 2^892 = 3.301840819597908e+268
# 2^893 = 6.603681639195816e+268
# 2^894 = 1.3207363278391631e+269
# 2^895 = 2.6414726556783262e+269
# 2^896 = 5.282945311356653e+269
# 2^897 = 1.0565890622713305e+270
# 2^898 = 2.113178124542661e+270
# 2^899 = 4.226356249085322e+270
# 2^900 = 8.452712498170644e+270
# 2^901 = 1.6905424996341288e+271
# 2^902 = 3.3810849992682576e+271
# 2^903 = 6.762169998536515e+271
# 2^904 = 1.352433999707303e+272
# 2^905 = 2.704867999414606e+272
# 2^906 = 5.409735998829212e+272
# 2^907 = 1.0819471997658424e+273
# 2^908 = 2.163894399531685e+273
# 2^909 = 4.32778879906337e+273
# 2^910 = 8.65557759812674e+273
# 2^911 = 1.731115519625348e+274
# 2^912 = 3.462231039250696e+274
# 2^913 = 6.924462078501392e+274
# 2^914 = 1.3848924157002783e+275
# 2^915 = 2.7697848314005566e+275
# 2^916 = 5.539569662801113e+275
# 2^917 = 1.1079139325602226e+276
# 2^918 = 2.2158278651204453e+276
# 2^919 = 4.431655730240891e+276
# 2^920 = 8.863311460481781e+276
# 2^921 = 1.7726622920963562e+277
# 2^922 = 3.5453245841927125e+277
# 2^923 = 7.090649168385425e+277
# 2^924 = 1.418129833677085e+278
# 2^925 = 2.83625966735417e+278
# 2^926 = 5.67251933470834e+278
# 2^927 = 1.134503866941668e+279
# 2^928 = 2.269007733883336e+279
# 2^1011 = 2.1944496275174755e+304
# 2^1012 = 4.388899255034951e+304
# 2^1013 = 8.777798510069902e+304
# 2^1014 = 1.7555597020139804e+305
# 2^1015 = 3.511119404027961e+305
# 2^1016 = 7.022238808055922e+305
# 2^1017 = 1.4044477616111843e+306
# 2^1018 = 2.8088955232223686e+306
# 2^1019 = 5.617791046444737e+306
# 2^1020 = 1.1235582092889474e+307
# 2^1021 = 2.247116418577895e+307
# 2^1022 = 4.49423283715579e+307
# 2^1023 = 8.98846567431158e+307
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Enquanto conseguirmos representar a potência de 2 sem perder precisão
#       5 while True:
# ----> 6     resultado = 2.0 ** potencia
#       7     print(f"2^{potencia} = {resultado}")
#       9     # Verifica se atingimos o limite de precisão
#
# OverflowError: (34, 'Numerical result out of range')

# %% [markdown]
# Q: As variáveis numéricas são imutáveis. Demonstre com exemplos as implicações desta afirmação;

# %%
x = 5.2
print("Valor original de x:", x)

x = x + 2.45
print("Novo valor de x:", x)
# Out:
# Valor original de x: 5.2
# Novo valor de x: 7.65

# %% [markdown]
# R: Em Python, as variáveis numéricas são consideradas imutáveis. Isso significa que, ao atribuir um novo valor a uma variável numérica, você está criando um novo objeto na memória e fazendo a variável apontar para esse novo objeto.

# %% [markdown]
# Q: Verifique quais métodos estão disponíveis para as variáveis de ponto flutuante;

# %%
#Verificando os métodos para as variáveis inteiras.
i = 2.3;
print(dir(i))
# Out:
# ['__abs__', '__add__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getformat__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__int__', '__le__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pow__', '__radd__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', 'as_integer_ratio', 'conjugate', 'fromhex', 'hex', 'imag', 'is_integer', 'real']

# %% [markdown]
# ### Exercício 6: Manipulando listas

# %% [markdown]
# Q: Dado o seguinte código, e antes de implementar, veja o que será impresso em cada caso:

# %%
L = [1,2,3,4,5,6,7,8,9]
print(L)
print(L[::-1])
print(L[-1::])
print(L[:-1:])
print(L[::-2])
print(L[-2::])
print(L[:-2:])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# [9]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [9, 7, 5, 3, 1]
# [8, 9]
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Q: Uma forma simplificada de determinar o seu animal no zodiaco chines é apresentada na seguinte tabela:

# %%
Signo = ["Macaco", "Galo", "Cão", "Porco", "Rato", "Boi", "Tigre", "Coelho", "Dragão", "Serpente", "Cavalo", "Carneiro"]

anoNascimento = int(input("Informe seu ano de nascimento: "))
print(f"O seu signo do zodiaco chinês é: {Signo[anoNascimento%12]}")
# Out:
# Informe seu ano de nascimento: 2000
# O seu signo do zodiaco chinês é: Dragão
